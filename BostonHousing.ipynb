# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
housing_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BostonHousing.csv')

# %%
housing_data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
print("Missing values in each column")
print(housing_data.isnull().sum())
print()
# Out:
# Missing values in each column
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
X = housing_data.drop('medv', axis = 'columns')
y = housing_data['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print('Coefficients:', model.coef_)
print(X_train.columns)
print('Intercept:', model.intercept_)
print('Mean Squared Error: %.2f' % mean_squared_error(y_test, y_pred))
print('Coefficient of Determination: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients: [-1.02545992e-01  4.52578679e-02 -1.65453658e-02  2.28836616e+00
#  -1.61677095e+01  3.71960388e+00  7.21669041e-03 -1.37549754e+00
#   3.26808526e-01 -1.22314169e-02 -1.00767686e+00  9.63631609e-03
#  -5.28307298e-01]
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat'],
#       dtype='object')
# Intercept: 36.41356750298306
# Mean Squared Error: 29.03
# Coefficient of Determination: 0.72

# %%
plt.scatter(y_test, y_pred, alpha = 0.8, marker = "^", color = "red")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')
